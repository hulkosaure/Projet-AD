# %%
import pandas as pd
import numpy as np

# %%
full_dataset = pd.read_csv("region.csv")
full_dataset
# Out:
#                        country                        region
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
# [243 rows x 2 columns]

# %%
co2_emissions_tonnes_per_person = pd.read_csv("co2_emissions_tonnes_per_person.csv")[["country","2018"]].rename({"2018":"co2_emissions_tonnes_per_person_2018"}, axis=1)
co2_emissions_tonnes_per_person
# Out:
#           country  co2_emissions_tonnes_per_person_2018
# 0     Afghanistan                                 0.254
# 1          Angola                                 1.120
# 2         Albania                                 1.590
# 3         Andorra                                 6.120
# 4             UAE                                21.400
# ..            ...                                   ...
# 189         Samoa                                 1.320
# 190         Yemen                                 0.356
# 191  South Africa                                 8.100
# 192        Zambia                                 0.302
# 193      Zimbabwe                                 0.850
#
# [194 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(co2_emissions_tonnes_per_person, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018
# 0                                   0.254
# 1                                   1.120
# 2                                   1.590
# 3                                   6.120
# ...

# %%
consumption_emission_cap = pd.read_csv("consumption_emission_cap.csv")[["country","2022"]].rename({"2022":"consumption_emission_cap_2022"}, axis=1)
consumption_emission_cap
# Out:
#           country  consumption_emission_cap_2022
# 0     Afghanistan                          0.385
# 1          Angola                          1.090
# 2         Albania                          2.140
# 3         Andorra                         13.300
# 4             UAE                         21.100
# ..            ...                            ...
# 189         Samoa                          1.090
# 190         Yemen                          0.365
# 191  South Africa                          5.460
# 192        Zambia                          0.415
# 193      Zimbabwe                          0.788
#
# [194 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(consumption_emission_cap, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
corruption_perception_index_cpi = pd.read_csv("corruption_perception_index_cpi.csv")[["country","2017"]].rename({"2017":"corruption_perception_index_cpi_2017"}, axis=1)
corruption_perception_index_cpi
# Out:
#           country  corruption_perception_index_cpi_2017
# 0     Afghanistan                                  15.0
# 1          Angola                                  19.0
# 2         Albania                                  38.0
# 3             UAE                                  71.0
# 4       Argentina                                  39.0
# ..            ...                                   ...
# 176       Vanuatu                                  43.0
# 177         Yemen                                  16.0
# 178  South Africa                                  43.0
# 179        Zambia                                  37.0
# 180      Zimbabwe                                  22.0
#
# [181 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(corruption_perception_index_cpi, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
energy_production_per_person = pd.read_csv("energy_production_per_person.csv")[["country","2009"]].rename({"2009":"energy_production_per_person_2009"}, axis=1)
energy_production_per_person
# Out:
#           country energy_production_per_person_2009
# 0          Angola                           0.00544
# 1         Albania                           0.00039
# 2             UAE                            0.0243
# 3       Argentina                           0.00202
# 4         Armenia                           0.00027
# ..            ...                               ...
# 130       Vietnam                           0.00088
# 131         Yemen                           0.00065
# 132  South Africa                           0.00323
# 133        Zambia                           0.00057
# 134      Zimbabwe                           0.00068
#
# [135 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(energy_production_per_person, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
energy_use_per_person = pd.read_csv("energy_use_per_person.csv")[["country","2014"]].rename({"2014":"energy_use_per_person_2014"}, axis=1)
energy_use_per_person
# Out:
#           country energy_use_per_person_2014
# 0          Angola                        541
# 1         Albania                        808
# 2             UAE                       7980
# 3       Argentina                       2030
# 4         Armenia                       1020
# ..            ...                        ...
# 168         Samoa                        NaN
# 169         Yemen                        NaN
# 170  South Africa                       2690
# 171        Zambia                        NaN
# 172      Zimbabwe                        NaN
#
# [173 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(energy_use_per_person, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
forest_coverage_percent = pd.read_csv("forest_coverage_percent.csv")[["country","2019"]].rename({"2019":"forest_coverage_percent_2019"}, axis=1)
forest_coverage_percent
# Out:
#           country  forest_coverage_percent_2019
# 0           Aruba                          2.33
# 1     Afghanistan                          1.85
# 2          Angola                         53.90
# 3        Anguilla                         61.10
# 4         Albania                         28.80
# ..            ...                           ...
# 226         Yemen                          1.04
# 227    Yugoslavia                           NaN
# 228  South Africa                         14.10
# 229        Zambia                         60.50
# 230      Zimbabwe                         45.20
#
# [231 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(forest_coverage_percent, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
gini_inegalite_de_repartition = pd.read_csv("gini_inegalite_de_repartition.csv")[["country","2018"]].rename({"2018":"gini_inegalite_de_repartition_2018"}, axis=1)
gini_inegalite_de_repartition
# Out:
#           country  gini_inegalite_de_repartition_2018
# 0          Angola                                51.3
# 1         Albania                                30.1
# 2             UAE                                26.0
# 3       Argentina                                41.3
# 4         Armenia                                34.4
# ..            ...                                 ...
# 162         Samoa                                 NaN
# 163         Yemen                                 NaN
# 164  South Africa                                 NaN
# 165        Zambia                                 NaN
# 166      Zimbabwe                                 NaN
#
# [167 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(gini_inegalite_de_repartition, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
hdi_human_development_index = pd.read_csv("hdi_human_development_index.csv")[["country","2021"]].rename({"2021":"hdi_human_development_index_2021"}, axis=1)
hdi_human_development_index
# Out:
#           country  hdi_human_development_index_2021
# 0     Afghanistan                             0.478
# 1          Angola                             0.586
# 2         Albania                             0.796
# 3         Andorra                             0.858
# 4             UAE                             0.911
# ..            ...                               ...
# 186         Samoa                             0.707
# 187         Yemen                             0.455
# 188  South Africa                             0.713
# 189        Zambia                             0.565
# 190      Zimbabwe                             0.593
#
# [191 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(hdi_human_development_index, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
menace_changement_climatique = pd.read_csv("menace_changement_climatique.csv")[["country","2021"]].rename({"2021":"menace_changement_climatique_2021"}, axis=1)
menace_changement_climatique
# Out:
#           country  menace_changement_climatique_2021
# 0     Afghanistan                               36.6
# 1         Albania                               63.9
# 2             UAE                               28.0
# 3       Argentina                               70.7
# 4         Armenia                               39.1
# ..            ...                                ...
# 138       Vietnam                               66.9
# 139         Yemen                                NaN
# 140  South Africa                               47.7
# 141        Zambia                               51.7
# 142      Zimbabwe                               50.1
#
# [143 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(menace_changement_climatique, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
percentage_women_in_national_parliaments = pd.read_csv("percentage_women_in_national_parliaments.csv")[["country","2021"]].rename({"2021":"percentage_women_in_national_parliaments_2021"}, axis=1)
percentage_women_in_national_parliaments
# Out:
#                             country  \
# 0                       Afghanistan
# 1                            Angola
# 2                           Albania
# 3                           Andorra
# 4                               UAE
# ..                              ...
# 179                          Uganda
# 180                         Ukraine
# 181  St. Vincent and the Grenadines
# 182                           Samoa
# 183                    South Africa
#
#      percentage_women_in_national_parliaments_2021
# 0                                            27.20
# 1                                            29.60
# 2                                            35.70
# 3                                            46.40
# 4                                            50.00
# ..                                             ...
# 179                                          33.80
# 180                                          20.30
# 181                                          18.20
# ...

# %%
full_dataset = full_dataset.merge(percentage_women_in_national_parliaments, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
personal_computers_per_100_people = pd.read_csv("personal_computers_per_100_people.csv")[["country","2005"]].rename({"2005":"personal_computers_per_100_people_2005"}, axis=1)
personal_computers_per_100_people
# Out:
#           country  personal_computers_per_100_people_2005
# 0           Aruba                                    7.97
# 1     Afghanistan                                    0.28
# 2          Angola                                    0.59
# 3        Anguilla                                   20.50
# 4         Albania                                    1.73
# ..            ...                                     ...
# 191         Samoa                                    1.89
# 192         Yemen                                    1.91
# 193  South Africa                                    8.36
# 194        Zambia                                    1.12
# 195      Zimbabwe                                    6.53
#
# [196 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(personal_computers_per_100_people, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
revenu_moyen_menage = pd.read_csv("revenu_moyen_menage.csv")[["country","2022"]].rename({"2022":"revenu_moyen_menage_2022"}, axis=1)
revenu_moyen_menage
# Out:
#           country revenu_moyen_menage_2022
# 0     Afghanistan                     2000
# 1          Angola                     1510
# 2         Albania                     3700
# 3             UAE                    35.6k
# 4       Argentina                    12.3k
# ..            ...                      ...
# 184         Samoa                     3900
# 185         Yemen                      999
# 186  South Africa                     4470
# 187        Zambia                     1270
# 188      Zimbabwe                     2540
#
# [189 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(revenu_moyen_menage, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
sex_ratio_all_age_groups = pd.read_csv("sex_ratio_all_age_groups.csv")[["country","2022"]].rename({"2022":"sex_ratio_all_age_groups_2022"}, axis=1)
sex_ratio_all_age_groups
# Out:
#           country  sex_ratio_all_age_groups_2022
# 0           Aruba                           89.2
# 1     Afghanistan                          102.0
# 2          Angola                           97.7
# 3        Anguilla                           95.8
# 4         Albania                           99.5
# ..            ...                            ...
# 231         Samoa                          104.0
# 232         Yemen                          102.0
# 233  South Africa                           94.9
# 234        Zambia                           97.4
# 235      Zimbabwe                           89.4
#
# [236 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(sex_ratio_all_age_groups, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
sustainable_developement_index = pd.read_csv("sustainable_developement_index.csv")[["country","2019"]].rename({"2019":"sustainable_developement_index_2019"}, axis=1)
sustainable_developement_index
# Out:
#           country  sustainable_developement_index_2019
# 0     Afghanistan                                 55.1
# 1          Angola                                 62.6
# 2         Albania                                 82.6
# 3             UAE                                 11.0
# 4       Argentina                                 77.7
# ..            ...                                  ...
# 159         Samoa                                 76.7
# 160         Yemen                                 50.6
# 161  South Africa                                 69.0
# 162        Zambia                                 62.9
# 163      Zimbabwe                                 61.5
#
# [164 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(sustainable_developement_index, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
child_mortality_0_5_year_olds_dying_per_1000_born = pd.read_csv("child_mortality_0_5_year_olds_dying_per_1000_born.csv")[["country","2022"]].rename({"2022":"child_mortality_0_5_year_olds_dying_per_1000_born_2022"}, axis=1)
child_mortality_0_5_year_olds_dying_per_1000_born
# Out:
#           country  child_mortality_0_5_year_olds_dying_per_1000_born_2022
# 0     Afghanistan                                              54.20
# 1          Angola                                              68.60
# 2         Albania                                               8.19
# 3         Andorra                                               2.79
# 4             UAE                                               6.79
# ..            ...                                                ...
# 192         Samoa                                              14.10
# 193         Yemen                                              53.50
# 194  South Africa                                              30.50
# 195        Zambia                                              51.50
# 196      Zimbabwe                                              41.30
#
# [197 rows x 2 columns]

# %%
full_dataset = full_dataset.merge(child_mortality_0_5_year_olds_dying_per_1000_born, on="country", how="outer")
full_dataset
# Out:
#                        country                        region  \
# 0                  Afghanistan                Asie-Pacifique
# 1                       Angola                       Afrique
# 2                      Albania              Europe orientale
# 3                      Andorra  Europe occidentale et autres
# 4                          UAE                Asie-Pacifique
# ..                         ...                           ...
# 238                   Holy See  Europe occidentale et autres
# 239                     Jersey  Europe occidentale et autres
# 240   St. Martin (French part)  Europe occidentale et autres
# 241             St. Barthélemy  Europe occidentale et autres
# 242  Sint Maarten (Dutch part)  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...

# %%
full_dataset = full_dataset.dropna(thresh=5)

# %%
full_dataset.to_csv("full_dataset.csv", index=False)
full_dataset
# Out:
#                    country                        region  \
# 0              Afghanistan                Asie-Pacifique
# 1                   Angola                       Afrique
# 2                  Albania              Europe orientale
# 3                  Andorra  Europe occidentale et autres
# 4                      UAE                Asie-Pacifique
# ..                     ...                           ...
# 218          New Caledonia  Europe occidentale et autres
# 222       French Polynesia  Europe occidentale et autres
# 226             San Marino  Europe occidentale et autres
# 232  Virgin Islands (U.S.)  Europe occidentale et autres
# 235                 Monaco  Europe occidentale et autres
#
#      co2_emissions_tonnes_per_person_2018  consumption_emission_cap_2022  \
# 0                                   0.254                          0.385
# 1                                   1.120                          1.090
# ...
